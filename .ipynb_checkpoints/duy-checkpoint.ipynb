# %%
from time import sleep
from selenium import webdriver  # Import from seleniumwire
from bs4 import BeautifulSoup
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
driver = webdriver.Chrome()

# Go to the Google home page
driver.get('https://understat.com/league/EPL/2020')
sleep(3)
page_source = driver.page_source

# %%
soup = BeautifulSoup(page_source, 'html.parser')

# %% [markdown]
# ![image.png](attachment:15a9e619-92e0-4442-9f40-bd203b5f37c7.png)

# %%
soup.find_all('td',attrs={'class':"align-right"})
# Out:
# [<td class="align-right">1</td>,
#  <td class="align-right">38</td>,
#  <td class="align-right">27</td>,
#  <td class="align-right">5</td>,
#  <td class="align-right">6</td>,
#  <td class="align-right">83</td>,
#  <td class="align-right">32</td>,
#  <td class="align-right">86</td>,
#  <td class="align-right nowrap">77.72<sup class="positive-value">-5.28</sup></td>,
#  <td class="align-right nowrap">30.61<sup class="negative-value">-1.39</sup></td>,
#  <td class="align-right nowrap">83.38<sup class="positive-value">-2.62</sup></td>,
#  <td class="align-right">2</td>,
#  <td class="align-right">38</td>,
#  <td class="align-right">21</td>,
#  <td class="align-right">11</td>,
#  <td class="align-right">6</td>,
#  <td class="align-right">73</td>,
#  <td class="align-right">44</td>,
#  <td class="align-right">74</td>,
#  <td class="align-right nowrap">63.17<sup class="positive-value">-9.83</sup></td>,
#  <td class="align-right nowrap">41.92<sup class="negative-value">-2.08</sup></td>,
# ...
